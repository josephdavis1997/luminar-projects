# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
# Out:
# Bad key "text.kerning_factor" on line 4 in
# C:\Users\Christy\anaconda3\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test_patch.mplstyle.
# You probably need to get an updated matplotlibrc file from
# https://github.com/matplotlib/matplotlib/blob/v3.1.3/matplotlibrc.template
# or from the matplotlib source distribution

# %%
data = pd.read_csv("data/abcnews-date-text.csv",error_bad_lines=False,nrows=10000)
data.head()
# Out:
#    publish_date                                      headline_text
# 0      20030219  aba decides against community broadcasting lic...
# 1      20030219     act fire witnesses must be aware of defamation
# 2      20030219     a g calls for infrastructure protection summit
# 3      20030219           air nz staff in aust strike for pay rise
# 4      20030219      air nz strike to affect australian travellers

# %%
data.shape
# Out:
# (10000, 2)

# %%
#checking for duplicates in headlines
data[data['headline_text'].duplicated(keep=False)].sort_values('headline_text').head(10)
# Out:
#       publish_date                             headline_text
# 9253      20030404   5 australian sars cases being monitored
# 9458      20030405   5 australian sars cases being monitored
# 6402      20030322     all walks of life follow protest path
# 6192      20030321     all walks of life follow protest path
# 6197      20030321       asio briefs crean on terrorist risk
# 6409      20030322       asio briefs crean on terrorist risk
# 6609      20030323    australia celebrates world cup victory
# 6813      20030324    australia celebrates world cup victory
# 7295      20030326  british forces mark time on basra fringe
# 7063      20030325  british forces mark time on basra fringe

# %%
data = data.drop_duplicates('headline_text')

# %%
data.shape
# Out:
# (9967, 2)

# %% [markdown]
# ### Model 01
#
# Removing Stopwords

# %%
#we are importiting 2 functions from sklearn for NLP

from sklearn.feature_extraction import text
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
len(text.ENGLISH_STOP_WORDS) #ENGLISH_STOP_WORDS is a frozenset where all the stopwords are listed
# Out:
# 318

# %%
text.ENGLISH_STOP_WORDS
# Out:
# frozenset({'a',
#            'about',
#            'above',
#            'across',
#            'after',
#            'afterwards',
#            'again',
#            'against',
#            'all',
#            'almost',
#            'alone',
#            'along',
#            'already',
#            'also',
#            'although',
#            'always',
#            'am',
#            'among',
#            'amongst',
#            'amoungst',
#            'amount',
#            'an',
#            'and',
#            'another',
#            'any',
#            'anyhow',
#            'anyone',
#            'anything',
#            'anyway',
#            'anywhere',
#            'are',
#            'around',
#            'as',
#            'at',
#            'back',
#            'be',
#            'became',
#            'because',
#            'become',
#            'becomes',
#            'becoming',
#            'been',
#            'before',
#            'beforehand',
#            'behind',
#            'being',
#            'below',
#            'beside',
#            'besides',
#            'between',
#            'beyond',
#            'bill',
#            'both',
#            'bottom',
#            'but',
#            'by',
#            'call',
#            'can',
#            'cannot',
#            'cant',
#            'co',
#            'con',
#            'could',
#            'couldnt',
#            'cry',
#            'de',
#            'describe',
#            'detail',
#            'do',
#            'done',
#            'down',
#            'due',
#            'during',
#            'each',
#            'eg',
#            'eight',
#            'either',
#            'eleven',
#            'else',
#            'elsewhere',
#            'empty',
#            'enough',
#            'etc',
#            'even',
#            'ever',
#            'every',
#            'everyone',
#            'everything',
#            'everywhere',
#            'except',
#            'few',
#            'fifteen',
#            'fifty',
#            'fill',
#            'find',
#            'fire',
#            'first',
#            'five',
#            'for',
#            'former',
#            'formerly',
#            'forty',
#            'found',
#            'four',
#            'from',
#            'front',
#            'full',
#            'further',
#            'get',
#            'give',
#            'go',
#            'had',
#            'has',
#            'hasnt',
#            'have',
#            'he',
#            'hence',
#            'her',
#            'here',
#            'hereafter',
#            'hereby',
#            'herein',
#            'hereupon',
#            'hers',
#            'herself',
#            'him',
#            'himself',
#            'his',
#            'how',
#            'however',
#            'hundred',
#            'i',
#            'ie',
#            'if',
#            'in',
#            'inc',
#            'indeed',
#            'interest',
#            'into',
#            'is',
#            'it',
#            'its',
#            'itself',
#            'keep',
#            'last',
#            'latter',
#            'latterly',
#            'least',
#            'less',
#            'ltd',
#            'made',
#            'many',
#            'may',
#            'me',
#            'meanwhile',
#            'might',
#            'mill',
#            'mine',
#            'more',
#            'moreover',
#            'most',
#            'mostly',
#            'move',
#            'much',
#            'must',
#            'my',
#            'myself',
#            'name',
#            'namely',
#            'neither',
#            'never',
#            'nevertheless',
#            'next',
#            'nine',
#            'no',
#            'nobody',
#            'none',
#            'noone',
#            'nor',
#            'not',
#            'nothing',
#            'now',
#            'nowhere',
#            'of',
#            'off',
#            'often',
#            'on',
#            'once',
#            'one',
#            'only',
#            'onto',
#            'or',
#            'other',
#            'others',
#            'otherwise',
#            'our',
#            'ours',
#            'ourselves',
#            'out',
#            'over',
#            'own',
#            'part',
#            'per',
#            'perhaps',
#            'please',
#            'put',
#            'rather',
#            're',
#            'same',
#            'see',
#            'seem',
#            'seemed',
#            'seeming',
#            'seems',
#            'serious',
#            'several',
#            'she',
#            'should',
#            'show',
#            'side',
#            'since',
#            'sincere',
#            'six',
#            'sixty',
#            'so',
#            'some',
#            'somehow',
#            'someone',
#            'something',
#            'sometime',
#            'sometimes',
#            'somewhere',
#            'still',
#            'such',
#            'system',
#            'take',
#            'ten',
#            'than',
#            'that',
#            'the',
#            'their',
#            'them',
#            'themselves',
#            'then',
#            'thence',
#            'there',
#            'thereafter',
#            'thereby',
#            'therefore',
#            'therein',
#            'thereupon',
#            'these',
#            'they',
#            'thick',
#            'thin',
#            'third',
#            'this',
#            'those',
#            'though',
#            'three',
#            'through',
#            'throughout',
#            'thru',
#            'thus',
#            'to',
#            'together',
#            'too',
#            'top',
#            'toward',
#            'towards',
#            'twelve',
#            'twenty',
#            'two',
#            'un',
#            'under',
#            'until',
#            'up',
#            'upon',
#            'us',
#            'very',
#            'via',
#            'was',
#            'we',
#            'well',
#            'were',
#            'what',
#            'whatever',
#            'when',
#            'whence',
#            'whenever',
#            'where',
#            'whereafter',
#            'whereas',
#            'whereby',
#            'wherein',
#            'whereupon',
#            'wherever',
#            'whether',
#            'which',
#            'while',
#            'whither',
#            'who',
#            'whoever',
#            'whole',
#            'whom',
#            'whose',
#            'why',
#            'will',
#            'with',
#            'within',
#            'without',
#            'would',
#            'yet',
#            'you',
#            'your',
#            'yours',
#            'yourself',
#            'yourselves'})

# %%
#selecting the stopwords and adding puctuations to it
punc = ['.', ',', '"', "'", '?', '!', ':', ';', '(', ')', '[', ']', '{', '}',"%"]
StopWords = text.ENGLISH_STOP_WORDS.union(punc)

# %%
StopWords
# Out:
# frozenset({'!',
#            '"',
#            '%',
#            "'",
#            '(',
#            ')',
#            ',',
#            '.',
#            ':',
#            ';',
#            '?',
#            '[',
#            ']',
#            'a',
#            'about',
#            'above',
#            'across',
#            'after',
#            'afterwards',
#            'again',
#            'against',
#            'all',
#            'almost',
#            'alone',
#            'along',
#            'already',
#            'also',
#            'although',
#            'always',
#            'am',
#            'among',
#            'amongst',
#            'amoungst',
#            'amount',
#            'an',
#            'and',
#            'another',
#            'any',
#            'anyhow',
#            'anyone',
#            'anything',
#            'anyway',
#            'anywhere',
#            'are',
#            'around',
#            'as',
#            'at',
#            'back',
#            'be',
#            'became',
#            'because',
#            'become',
#            'becomes',
#            'becoming',
#            'been',
#            'before',
#            'beforehand',
#            'behind',
#            'being',
#            'below',
#            'beside',
#            'besides',
#            'between',
#            'beyond',
#            'bill',
#            'both',
#            'bottom',
#            'but',
#            'by',
#            'call',
#            'can',
#            'cannot',
#            'cant',
#            'co',
#            'con',
#            'could',
#            'couldnt',
#            'cry',
#            'de',
#            'describe',
#            'detail',
#            'do',
#            'done',
#            'down',
#            'due',
#            'during',
#            'each',
#            'eg',
#            'eight',
#            'either',
#            'eleven',
#            'else',
#            'elsewhere',
#            'empty',
#            'enough',
#            'etc',
#            'even',
#            'ever',
#            'every',
#            'everyone',
#            'everything',
#            'everywhere',
#            'except',
#            'few',
#            'fifteen',
#            'fifty',
#            'fill',
#            'find',
#            'fire',
#            'first',
#            'five',
#            'for',
#            'former',
#            'formerly',
#            'forty',
#            'found',
#            'four',
#            'from',
#            'front',
#            'full',
#            'further',
#            'get',
#            'give',
#            'go',
#            'had',
#            'has',
#            'hasnt',
#            'have',
#            'he',
#            'hence',
#            'her',
#            'here',
#            'hereafter',
#            'hereby',
#            'herein',
#            'hereupon',
#            'hers',
#            'herself',
#            'him',
#            'himself',
#            'his',
#            'how',
#            'however',
#            'hundred',
#            'i',
#            'ie',
#            'if',
#            'in',
#            'inc',
#            'indeed',
#            'interest',
#            'into',
#            'is',
#            'it',
#            'its',
#            'itself',
#            'keep',
#            'last',
#            'latter',
#            'latterly',
#            'least',
#            'less',
#            'ltd',
#            'made',
#            'many',
#            'may',
#            'me',
#            'meanwhile',
#            'might',
#            'mill',
#            'mine',
#            'more',
#            'moreover',
#            'most',
#            'mostly',
#            'move',
#            'much',
#            'must',
#            'my',
#            'myself',
#            'name',
#            'namely',
#            'neither',
#            'never',
#            'nevertheless',
#            'next',
#            'nine',
#            'no',
#            'nobody',
#            'none',
#            'noone',
#            'nor',
#            'not',
#            'nothing',
#            'now',
#            'nowhere',
#            'of',
#            'off',
#            'often',
#            'on',
#            'once',
#            'one',
#            'only',
#            'onto',
#            'or',
#            'other',
#            'others',
#            'otherwise',
#            'our',
#            'ours',
#            'ourselves',
#            'out',
#            'over',
#            'own',
#            'part',
#            'per',
#            'perhaps',
#            'please',
#            'put',
#            'rather',
#            're',
#            'same',
#            'see',
#            'seem',
#            'seemed',
#            'seeming',
#            'seems',
#            'serious',
#            'several',
#            'she',
#            'should',
#            'show',
#            'side',
#            'since',
#            'sincere',
#            'six',
#            'sixty',
#            'so',
#            'some',
#            'somehow',
#            'someone',
#            'something',
#            'sometime',
#            'sometimes',
#            'somewhere',
#            'still',
#            'such',
#            'system',
#            'take',
#            'ten',
#            'than',
#            'that',
#            'the',
#            'their',
#            'them',
#            'themselves',
#            'then',
#            'thence',
#            'there',
#            'thereafter',
#            'thereby',
#            'therefore',
#            'therein',
#            'thereupon',
#            'these',
#            'they',
#            'thick',
#            'thin',
#            'third',
#            'this',
#            'those',
#            'though',
#            'three',
#            'through',
#            'throughout',
#            'thru',
#            'thus',
#            'to',
#            'together',
#            'too',
#            'top',
#            'toward',
#            'towards',
#            'twelve',
#            'twenty',
#            'two',
#            'un',
#            'under',
#            'until',
#            'up',
#            'upon',
#            'us',
#            'very',
#            'via',
#            'was',
#            'we',
#            'well',
#            'were',
#            'what',
#            'whatever',
#            'when',
#            'whence',
#            'whenever',
#            'where',
#            'whereafter',
#            'whereas',
#            'whereby',
#            'wherein',
#            'whereupon',
#            'wherever',
#            'whether',
#            'which',
#            'while',
#            'whither',
#            'who',
#            'whoever',
#            'whole',
#            'whom',
#            'whose',
#            'why',
#            'will',
#            'with',
#            'within',
#            'without',
#            'would',
#            'yet',
#            'you',
#            'your',
#            'yours',
#            'yourself',
#            'yourselves',
#            '{',
#            '}'})

# %%
len(StopWords)
# Out:
# 333

# %%
desc = data['headline_text'].values
desc #dataframe column is converted to an array.
# Out:
# array(['aba decides against community broadcasting licence',
#        'act fire witnesses must be aware of defamation',
#        'a g calls for infrastructure protection summit', ...,
#        'vic nats leave door open on coalition',
#        'waterfall survivors tell of train speeding before',
#        'water wont be moved without studies gallop'], dtype=object)

# %%
vectorizer = TfidfVectorizer(stop_words = StopWords)
X=vectorizer.fit_transform(desc) #transorming desc to corresponding vector.

# %%
print("X is the TDIDF vector with %s rows and %s unique words(features)"%(X.shape[0],X.shape[1]))
# Out:
# X is the TDIDF vector with 9967 rows and 9820 unique words(features)

# %%
word_features = vectorizer.get_feature_names() #identiying the word from the vectors
word_features[500:510]
# Out:
# ['anasta',
#  'ancestral',
#  'anchors',
#  'ancient',
#  'anderson',
#  'andersson',
#  'andy',
#  'angeles',
#  'anger',
#  'angered']

# %%
X.shape  #we have 19938 observations and 13838 unique words present in the corpus 
# X will be the vector corresponding to data['headline_text']. This can be used for any ML tasks.
# Out:
# (9967, 9820)

# %% [markdown]
# ### Model 2
#
# Case Conversion
#
# Tokenization
#
# Stemming
#
# Removing Stopwords

# %%
#we are adding stemming  and tokenization to the preprocessing from the package NLTK
from nltk.stem.snowball import SnowballStemmer #SnowballStemmer is a stemming algorithm
from nltk.tokenize import RegexpTokenizer

# %%
stemmer = SnowballStemmer(language='english')
tokenizer = RegexpTokenizer(pattern=r'[a-zA-Z\']+')

def tokenize(text):
   
    return [stemmer.stem(word) for word in tokenizer.tokenize(text.lower())] 

#Step1 - Convert text to lower
#step2 - tokenize the text
#step3 - Stem the tokenized text

#lower case
#tokenize
#stemming

# %%
def tokenize_function(text):
    lower_words = text.lower()
    tokenized = tokenizer.tokenize(lower_words)
    stem_list  = list()
    for x in tokenized:
        stem_list.append(stemmer.stem(x))
    return stem_list

# %%
tokenize_function("INDIA launched  2 new satelites, and the launch is Success")
# Out:
# ['india', 'launch', 'new', 'satelit', 'and', 'the', 'launch', 'is', 'success']

# %%
tokenize("INDIA launched  2 new satelites, and the launch is Success")
# Out:
# ['india', 'launch', 'new', 'satelit', 'and', 'the', 'launch', 'is', 'success']

# %%
tokenizer1 = RegexpTokenizer(r'[a-zA-Z0-9\']+') #new RegEx for including numbers
tokenizer1.tokenize("INDIA launch  2 new satelites, and the launch is success")
# Out:
# ['INDIA',
#  'launch',
#  '2',
#  'new',
#  'satelites',
#  'and',
#  'the',
#  'launch',
#  'is',
#  'success']

# %%
vectorizer2 = TfidfVectorizer(stop_words = StopWords, tokenizer = tokenize) #we are giving StopWords and tokenize function as the arguments
X2 = vectorizer2.fit_transform(desc)
word_features2 = vectorizer2.get_feature_names()
print(len(word_features2))
# Out:
# C:\Users\Christy\anaconda3\lib\site-packages\sklearn\feature_extraction\text.py:386: UserWarning: Your stop_words may be inconsistent with your preprocessing. Tokenizing the stop words generated tokens ['abov', 'afterward', 'alon', 'alreadi', 'alway', 'ani', 'anoth', 'anyon', 'anyth', 'anywher', 'becam', 'becaus', 'becom', 'befor', 'besid', 'cri', 'describ', 'dure', 'els', 'elsewher', 'empti', 'everi', 'everyon', 'everyth', 'everywher', 'fifti', 'forti', 'henc', 'hereaft', 'herebi', 'howev', 'hundr', 'inde', 'mani', 'meanwhil', 'moreov', 'nobodi', 'noon', 'noth', 'nowher', 'onc', 'onli', 'otherwis', 'ourselv', 'perhap', 'pleas', 'sever', 'sinc', 'sincer', 'sixti', 'someon', 'someth', 'sometim', 'somewher', 'themselv', 'thenc', 'thereaft', 'therebi', 'therefor', 'togeth', 'twelv', 'twenti', 'veri', 'whatev', 'whenc', 'whenev', 'wherea', 'whereaft', 'wherebi', 'wherev', 'whi', 'yourselv'] not in stop_words.
#   'stop_words.' % sorted(inconsistent))
# 6909

# %%
X2.shape
# Out:
# (9967, 6909)

# %%
print("X2 is the TDIDF vector with %s rows and %s unique words(features)"%(X2.shape[0],X2.shape[1]))
# Out:
# X2 is the TDIDF vector with 9967 rows and 6909 unique words(features)

# %%
words = vectorizer2.get_feature_names()

# %%
words
# Out:
# ['aa',
#  'aac',
#  'ab',
#  'aba',
#  'abalon',
#  'abandon',
#  'abar',
#  'abattoir',
#  'abbott',
#  'abc',
#  'abdic',
#  'abduct',
#  'abid',
#  'abigroup',
#  'abil',
#  'abl',
#  'ablaz',
#  'aboard',
#  'abolit',
#  'aborigin',
#  'abort',
#  'abov',
#  'abreast',
#  'abroad',
#  'absenc',
#  'absent',
#  'abu',
#  'abund',
#  'abus',
#  'abysm',
#  'ac',
#  'aca',
#  'academ',
#  'academi',
#  'acapulco',
#  'acb',
#  'accc',
#  'accent',
#  'accept',
#  'access',
#  'accid',
#  'accident',
#  'accommod',
#  'account',
#  'accredit',
#  'accus',
#  'ace',
#  'aceh',
#  'achiev',
#  'acid',
#  'acknowledg',
#  'acoss',
#  'acquir',
#  'acquisit',
#  'acquit',
#  'act',
#  'action',
#  'activ',
#  'activist',
#  'actor',
#  'actress',
#  'actu',
#  'acu',
#  'ad',
#  'adam',
#  'add',
#  'addict',
#  'addit',
#  'address',
#  'adelaid',
#  'adequ',
#  'adf',
#  'adjourn',
#  'adjust',
#  'administr',
#  'admir',
#  'admit',
#  'adopt',
#  'adriatico',
#  'adult',
#  'advanc',
#  'advantag',
#  'adventur',
#  'advertis',
#  'advic',
#  'advis',
#  'advisori',
#  'advoc',
#  'aec',
#  'aek',
#  'aerial',
#  'aerodynam',
#  'aeronaut',
#  'affair',
#  'affect',
#  'affili',
#  'afford',
#  'afghan',
#  'afghanistan',
#  'afl',
#  'afloat',
#  'afma',
#  'afp',
#  'afraid',
#  'africa',
#  'african',
#  'afridi',
#  'aftershock',
#  'ag',
#  'agassi',
#  'age',
#  'agenc',
#  'agenda',
#  'agent',
#  'agfest',
#  'agforc',
#  'aggress',
#  'agl',
#  'ago',
#  'agoni',
#  'agre',
#  'agreement',
#  'agricultur',
#  'aground',
#  'ah',
#  'ahead',
#  'ai',
#  'aid',
#  'ail',
#  'aim',
#  'air',
#  'airbas',
#  'airborn',
#  'aircraft',
#  'airfield',
#  'airlift',
#  'airlin',
#  'airmen',
#  'airpark',
#  'airport',
#  'airspac',
#  'airwomen',
#  'ajax',
#  'akbar',
#  'akram',
#  'al',
#  'alain',
#  'alarm',
#  'albani',
#  'albert',
#  'album',
#  'alburi',
#  'alcohol',
#  'aldoga',
#  'alert',
#  'alga',
#  'algal',
#  'algeria',
#  'algerian',
#  'ali',
#  'alianza',
#  'alic',
#  'alien',
#  'alight',
#  'align',
#  'alinghi',
#  'aliv',
#  'allan',
#  'alleg',
#  'allergi',
#  'alli',
#  'allianc',
#  'alloc',
#  'allow',
#  'alon',
#  'alp',
#  'alpolfo',
#  'alreadi',
#  'alsac',
#  'alston',
#  'alterc',
#  'altern',
#  'aluminium',
#  'ama',
#  'amateur',
#  'amaz',
#  'ambassador',
#  'ambit',
#  'ambiti',
#  'ambo',
#  'ambul',
#  'amc',
#  'amcor',
#  'amend',
#  'ameri',
#  'america',
#  'american',
#  'amid',
#  'amidst',
#  'amino',
#  'ammunit',
#  'amnesti',
#  'amoeba',
#  'amoruso',
#  'amp',
#  'amphetamin',
#  'amput',
#  'ampute',
#  'amrozi',
#  'analyst',
#  'anasta',
#  'ancestr',
#  'anchor',
#  'ancient',
#  'anderson',
#  'andersson',
#  'andi',
#  'angel',
#  'anger',
#  'angl',
#  'angler',
#  'anglian',
#  'anglican',
#  'angri',
#  'ani',
#  'anim',
#  'ankl',
#  'anlezark',
#  'annan',
#  'annihil',
#  'anniversari',
#  'announc',
#  'annual',
#  'anoth',
#  'ansar',
#  'ansett',
#  'answer',
#  'ant',
#  'antarct',
#  'antarctica',
#  'anthem',
#  'anthrax',
#  'anti',
#  'antic',
#  'antidot',
#  'anwar',
#  'anxieti',
#  'anxious',
#  'anz',
#  'anzac',
#  'aoc',
#  'apach',
#  'apart',
#  'apartheid',
#  'ape',
#  'aplenti',
#  'apn',
#  'apolog',
#  'apologis',
#  'appal',
#  'appar',
#  'appeal',
#  'appear',
#  'appeas',
#  'applaud',
#  'appli',
#  'applic',
#  'appoint',
#  'apprentic',
#  'apprenticeship',
#  'approach',
#  'appropri',
#  'approv',
#  'apra',
#  'april',
#  'aprilia',
#  'aquacultur',
#  'aquat',
#  'aquif',
#  'arab',
#  'arabia',
#  'arabian',
#  'arafat',
#  'arafura',
#  'aramac',
#  'arazi',
#  'arbitr',
#  'archaeolog',
#  'archaeologist',
#  'archbishop',
#  'archdioces',
#  'archibald',
#  'architect',
#  'architectur',
#  'ardil',
#  'ardmona',
#  'area',
#  'argentin',
#  'argentina',
#  'argentinian',
#  'argu',
#  'argument',
#  'aris',
#  'aristocrat',
#  'arizona',
#  'arm',
#  'armageddon',
#  'armchair',
#  'armenian',
#  'armi',
#  'armidal',
#  'armour',
#  'armstrong',
#  'arnett',
#  'arnhem',
#  'arrang',
#  'arrest',
#  'arriv',
#  'arrog',
#  'arron',
#  'arrow',
#  'arroyo',
#  'arsenal',
#  'arson',
#  'arsonist',
#  'art',
#  'arteri',
#  'arthur',
#  'articl',
#  'artifici',
#  'artilleri',
#  'artist',
#  'artwork',
#  'aru',
#  'asa',
#  'asbesto',
#  'ash',
#  'asham',
#  'ashford',
#  'asia',
#  'asian',
#  'asic',
#  'asid',
#  'asio',
#  'ask',
#  'asphalt',
#  'aspirin',
#  'assassin',
#  'assault',
#  'assess',
#  'asset',
#  'assist',
#  'associ',
#  'assum',
#  'assur',
#  'asthma',
#  'astound',
#  'astro',
#  'astronom',
#  'asx',
#  'asylum',
#  'atalanta',
#  'atapattu',
#  'athen',
#  'athlet',
#  'atkinson',
#  'atlant',
#  'atletico',
#  'atm',
#  'ato',
#  'atom',
#  'atop',
#  'atp',
#  'atroc',
#  'atsic',
#  'attach',
#  'attack',
#  'attempt',
#  'attend',
#  'attent',
#  'attitud',
#  'attorney',
#  'attract',
#  'attrit',
#  'atwal',
#  'auckland',
#  'auction',
#  'audit',
#  'augusta',
#  'auiron',
#  'aus',
#  'ausmelt',
#  'aussi',
#  'aust',
#  'austeel',
#  'austereo',
#  'australia',
#  'australian',
#  'austria',
#  'authent',
#  'author',
#  'autopsi',
#  'autumn',
#  'auxerr',
#  'avail',
#  'avalanch',
#  'ave',
#  'aveng',
#  'avenu',
#  'avert',
#  'aviat',
#  'avocado',
#  'avoid',
#  'await',
#  'awaken',
#  'awar',
#  'award',
#  'away',
#  'awb',
#  'awe',
#  'awol',
#  'awu',
#  'axe',
#  'axel',
#  'axeman',
#  'axi',
#  'aynaoui',
#  'ayr',
#  'azzurri',
#  'b',
#  'baath',
#  'babi',
#  'babri',
#  'babyhol',
#  'bacher',
#  'bachtiar',
#  'backbench',
#  'backdown',
#  'backdrop',
#  'backflip',
#  'backhand',
#  'backlash',
#  'backpack',
#  'backped',
#  'backstrok',
#  'bacon',
#  'bad',
#  'baddeley',
#  'baffl',
#  'bafta',
#  'bag',
#  'bagdad',
#  'baggi',
#  'baghdad',
#  'bail',
#  'baildon',
#  'bairnsdal',
#  'bait',
#  'bakar',
#  'balanc',
#  'balconi',
#  'bali',
#  'ball',
#  'ballack',
#  'ballad',
#  'ballarat',
#  'ballina',
#  'ballist',
#  'balloon',
#  'ballot',
#  'ballymor',
#  'ban',
#  'banana',
#  'bandit',
#  'bangkok',
#  'bangladesh',
#  'bangladeshi',
#  'bank',
#  'bankcard',
#  'bankruptci',
#  'bankstown',
#  'baptist',
#  'bar',
#  'barbi',
#  'barca',
#  'barcelona',
#  'barcoo',
#  'bare',
#  'barg',
#  'bargain',
#  'bargin',
#  'bariton',
#  'barmera',
#  'barr',
#  'barra',
#  'barrag',
#  'barri',
#  'barrichello',
#  'barrier',
#  'barrist',
#  'barthez',
#  'bartholomeuz',
#  'bartlett',
#  'barwon',
#  'base',
#  'basebal',
#  'basel',
#  'bash',
#  'bashir',
#  'basi',
#  'basic',
#  'basin',
#  'basra',
#  'bass',
#  'basslink',
#  'bat',
#  'batchelor',
#  'bateman',
#  'bathhous',
#  'batman',
#  'battalion',
#  'batten',
#  'batteux',
#  'battl',
#  'baxter',
#  'bay',
#  'bayarri',
#  'bayer',
#  'bayern',
#  'bayswat',
#  'bcc',
#  'beach',
#  'beachley',
#  'beacon',
#  'bear',
#  'beat',
#  'beaten',
#  'beatl',
#  'beatti',
#  'beazley',
#  'becaus',
#  'beckham',
#  'becom',
#  'bed',
#  'bedi',
#  'bedouin',
#  'bedroom',
#  'beechford',
#  'beef',
#  'beekeep',
#  'beer',
#  'beetl',
#  'befor',
#  'beg',
#  'bega',
#  'begay',
#  'beggar',
#  'begin',
#  'begun',
#  'behav',
#  'behaviour',
#  'beij',
#  'beirut',
#  'bekel',
#  'belfast',
#  'belgian',
#  'belgium',
#  'belgrad',
#  'believ',
#  'belittl',
#  'bell',
#  'bellami',
#  'belohvoscik',
#  'belt',
#  'bench',
#  'benchmark',
#  'bendigo',
#  'beneath',
#  'benefit',
#  'benitez',
#  'bequest',
#  'berger',
#  'bergkamp',
#  'berlin',
#  'bern',
#  'bernstein',
#  'berri',
#  'berth',
#  'best',
#  'bet',
#  'beti',
#  'better',
#  'bettini',
#  'bevan',
#  'bewar',
#  'bhp',
#  'bhumibol',
#  'bhutan',
#  'bias',
#  'bichel',
#  'bicker',
#  'bid',
#  'big',
#  'biggest',
#  'bike',
#  'bikeway',
#  'biki',
#  'bilater',
#  'bilbi',
#  'billion',
#  'billionair',
#  'billiton',
#  'bin',
#  'bing',
#  'bio',
#  'biolog',
#  'biologist',
#  'biospher',
#  'bipartisan',
#  'bird',
#  'birdi',
#  'birdsvill',
#  'birmingham',
#  'birth',
#  'birthday',
#  'biscayn',
#  'bishop',
#  'bite',
#  'black',
#  'blackal',
#  'blacklock',
#  'blackmail',
#  'blackout',
#  'blackshirt',
#  'blair',
#  'blake',
#  'blame',
#  'blast',
#  'blatant',
#  'blatter',
#  'blayney',
#  'blaze',
#  'bleed',
#  'blend',
#  'blew',
#  'blewett',
#  'bligh',
#  'blight',
#  'blignaut',
#  'blind',
#  'blitz',
#  'blix',
#  'blizzard',
#  'blob',
#  'block',
#  'blockad',
#  'bloke',
#  'blood',
#  'bloodi',
#  'bloodier',
#  'bloodsh',
#  'bloom',
#  'blow',
#  'blowout',
#  'blue',
#  'blunder',
#  'bmw',
#  'board',
#  'boarder',
#  'boardshort',
#  'boat',
#  'boati',
#  'boavista',
#  'boca',
#  'bochum',
#  'bodi',
#  'bodyguard',
#  'bog',
#  'boksic',
#  'bold',
#  'bolivar',
#  'bolivia',
#  'bolster',
#  'bolton',
#  'bomaderri',
#  'bomb',
#  'bombard',
#  'bombay',
#  'bomber',
#  'bond',
#  'bone',
#  'bonlac',
#  'bonus',
#  'boodnikoff',
#  'book',
#  'booki',
#  'booklet',
#  'boom',
#  'boon',
#  'boonah',
#  'boost',
#  'boot',
#  'booz',
#  'bora',
#  'bordeau',
#  'border',
#  'bore',
#  'born',
#  'boro',
#  'borroloola',
#  'borrow',
#  'bortolo',
#  'bosnian',
#  'bosnich',
#  'boss',
#  'boston',
#  'botan',
#  'botch',
#  'botero',
#  'bottl',
#  'boucher',
#  'bougainvill',
#  'bought',
#  'boulami',
#  'boulder',
#  'boulia',
#  'bounc',
#  'bound',
#  'boundari',
#  'bounti',
#  'bourk',
#  'bout',
#  'bow',
#  'bowden',
#  'bowl',
#  'bowler',
#  'box',
#  'boy',
#  'boycot',
#  'boycott',
#  'boyfriend',
#  'bp',
#  'brace',
#  'brack',
#  'bracken',
#  'bradman',
#  'brain',
#  'brainstorm',
#  'brake',
#  'branch',
#  'brand',
#  'brasher',
#  'brave',
#  'braveri',
#  'brawl',
#  'brazil',
#  'brazilian',
#  'breach',
#  'break',
#  'breakaway',
#  'breakdown',
#  'breaker',
#  'breakout',
#  'breakthrough',
#  'breast',
#  'breastfe',
#  'breastfeed',
#  'breaststrok',
#  'breath',
#  'bred',
#  'breed',
#  'brew',
#  'brick',
#  'bridg',
#  'bridgehead',
#  'brief',
#  'briefcas',
#  'brigadi',
#  'bright',
#  'brighten',
#  'brighter',
#  'brighton',
#  'brillianc',
#  'bring',
#  'brink',
#  'bris',
#  'brisban',
#  'bristol',
#  'brit',
#  'britain',
#  'british',
#  'briton',
#  'brizuela',
#  'brl',
#  'broadband',
#  'broadcast',
#  'broader',
#  'broadford',
#  'broadsound',
#  'broadway',
#  'brochur',
#  'brockovich',
#  'brogden',
#  'broke',
#  'broken',
#  'brom',
#  'bronco',
#  'brookdal',
#  'brooloo',
#  'broom',
#  'brothel',
#  'brother',
#  'brown',
#  'brownlow',
#  'brumbi',
#  'brundl',
#  'brutal',
#  'bryant',
#  'bryce',
#  'buchanan',
#  'bucher',
#  'buddhist',
#  'budget',
#  'bueno',
#  'buffer',
#  'bug',
#  'buggi',
#  'build',
#  'builder',
#  'built',
#  'bulk',
#  'bull',
#  'bulldog',
#  'bulldoz',
#  'bullet',
#  'bulli',
#  'bumper',
#  'bun',
#  'bunburi',
#  'bundaberg',
#  'bundesliga',
#  'bundoora',
#  'bungl',
#  'bunker',
#  'bunni',
#  'buoyant',
#  'burden',
#  'bureau',
#  'bureaucraci',
#  'bureaucrat',
#  'burger',
#  'burglar',
#  'burglari',
#  'buri',
#  'burk',
#  'burleigh',
#  'burley',
#  'burma',
#  'burmes',
#  'burn',
#  'burnley',
#  'burnt',
#  'burrendong',
#  'burrinjuck',
#  'burrup',
#  'burst',
#  'burston',
#  'burtson',
#  'burundi',
#  'bus',
#  'busch',
#  'buse',
#  'bush',
#  'bushfir',
#  'bushland',
#  'bushmast',
#  'bushrang',
#  'bushwalk',
#  'busi',
#  'busier',
#  'businessman',
#  'busker',
#  'busselton',
#  'bust',
#  'buster',
#  'butcher',
#  'butler',
#  'butt',
#  'butterfli',
#  'button',
#  'buy',
#  'buyer',
#  'byo',
#  'bypass',
#  'c',
#  'cabin',
#  'cabinet',
#  'cabooltur',
#  'caddi',
#  'cadel',
#  'cafe',
#  'cafeteria',
#  'cafl',
#  'cain',
#  'cairn',
#  'calcul',
#  'calder',
#  'caledonia',
#  'caley',
#  'calf',
#  'cali',
#  'california',
#  'californian',
#  'calleri',
#  'callous',
#  'callus',
#  'calm',
#  'caloundra',
#  'caltex',
#  'cambodia',
#  'cambodian',
#  'came',
#  'camera',
#  'cameraman',
#  'camp',
#  'campaign',
#  'campasp',
#  'campbel',
#  'camplin',
#  'campsi',
#  'campus',
#  'canada',
#  'canadian',
#  'canal',
#  'canberra',
#  'cancel',
#  'cancer',
#  'candid',
#  'candlehold',
#  'cane',
#  'canegrow',
#  'canio',
#  'cannabi',
#  'canning',
#  'cannon',
#  'cano',
#  'canoeist',
#  'canola',
#  'canterburi',
#  'canvass',
#  'canyon',
#  'cap',
#  'capabl',
#  'capac',
#  'cape',
#  'capel',
#  'capella',
#  'capello',
#  'capit',
#  'capitalis',
#  'capitul',
#  'capriati',
#  'capsicum',
#  'capsiz',
#  'captain',
#  'captainci',
#  'captiv',
#  'captur',
#  'car',
#  'carat',
#  'caravan',
#  'carcass',
#  'card',
#  'cardiac',
#  'cardiologist',
#  'care',
#  'career',
#  'careflight',
#  'carer',
#  'caretak',
#  'carew',
#  'carey',
#  'cargil',
#  'caribbean',
#  'caricatur',
#  'carl',
#  'carlo',
#  'carlton',
#  'carmichael',
#  'carnag',
#  'carniv',
#  'carpark',
#  'carpentaria',
#  'carpet',
#  'carr',
#  'carri',
#  'carrier',
#  'carrigan',
#  'carseldin',
#  'cart',
#  ...]

# %%
X2 #sparse matrix means most of the elements are 0

#Sparse matrix is a matrix which contains very few non-zero elements.
# Out:
# <9967x6909 sparse matrix of type '<class 'numpy.float64'>'
# 	with 49015 stored elements in Compressed Sparse Row format>

# %%
from sklearn.cluster import KMeans  #calculating wcss for identifying the value for K
wcss = []
for i in range(1,20):
    print("cluster",i)
    kmeans = KMeans(n_clusters=i,init='k-means++',max_iter=300,n_init=10,random_state=0)
    kmeans.fit(X2)
    wcss.append(kmeans.inertia_)
# Out:
# cluster 1
# cluster 2
# cluster 3
# cluster 4
# cluster 5
# cluster 6
# cluster 7
# cluster 8
# cluster 9
# cluster 10
# cluster 11
# cluster 12
# cluster 13
# cluster 14
# cluster 15
# cluster 16
# cluster 17
# cluster 18
# cluster 19

# %%
plt.plot(range(1,20),wcss)
plt.title('The Elbow Method')
plt.xlabel('Number of clusters')
plt.ylabel('WCSS')
#plt.savefig('elbow.png')
plt.show()

# %%
kmeans = KMeans(n_clusters = 6, n_init = 20, n_jobs = 1) # n_init(number of iterations for clsutering) n_jobs(number of cpu cores to use)
kmeans.fit(X2)
# Out:
# C:\Users\Christy\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:974: FutureWarning: 'n_jobs' was deprecated in version 0.23 and will be removed in 0.25.
#   " removed in 0.25.", FutureWarning)
# KMeans(n_clusters=6, n_init=20, n_jobs=1)

# %%
common_words = kmeans.cluster_centers_.argsort()[:,-1:-16:-1] #checking for the most ffrequent words in each cluster
for num, centroid in enumerate(common_words):
    print(str(num) + ' : ' + ', '.join(words[word] for word in centroid))
# Out:
# 0 : war, polic, plan, new, iraqi, win, protest, baghdad, anti, probe, say, ralli, forc, pm, arrest
# 1 : council, claim, say, warn, rain, world, fund, nsw, water, report, cup, death, urg, continu, set
# 2 : iraq, war, say, missil, troop, howard, post, destroy, blair, deni, pm, bush, british, bomb, turkey
# 3 : man, charg, face, murder, court, stab, polic, jail, death, miss, assault, arrest, hospit, search, u
# 4 : govt, vic, sa, nsw, urg, fund, wa, qld, local, claim, consid, reject, nt, fed, tas
# 5 : kill, soldier, crash, accid, attack, car, troop, palestinian, suspect, baghdad, iraq, gaza, wound, iraqi, isra

# %%
result = kmeans.predict(X2)

# %%
data['result']=result #adding a new column to dataframe

# %%
data.head(25)
# Out:
#     publish_date                                      headline_text  result
# 0       20030219  aba decides against community broadcasting lic...       1
# 1       20030219     act fire witnesses must be aware of defamation       1
# 2       20030219     a g calls for infrastructure protection summit       1
# 3       20030219           air nz staff in aust strike for pay rise       1
# 4       20030219      air nz strike to affect australian travellers       1
# 5       20030219                  ambitious olsson wins triple jump       0
# 6       20030219         antic delighted with record breaking barca       1
# 7       20030219  aussie qualifier stosur wastes four memphis match       1
# 8       20030219       aust addresses un security council over iraq       2
# 9       20030219         australia is locked into war timetable opp       0
# 10      20030219  australia to contribute 10 million in aid to iraq       2
# 11      20030219  barca take record as robson celebrates birthda...       1
# 12      20030219                         bathhouse plans move ahead       0
# 13      20030219      big hopes for launceston cycling championship       1
# 14      20030219             big plan to boost paroo water supplies       0
# 15      20030219             blizzard buries united states in bills       1
# 16      20030219     brigadier dismisses reports troops harassed in       1
# 17      20030219     british combat troops arriving daily in kuwait       1
# 18      20030219         bryant leads lakers to double overtime win       0
# 19      20030219           bushfire victims urged to see centrelink       1
# 20      20030219    businesses should prepare for terrorist attacks       1
# 21      20030219    calleri avenges final defeat to eliminate massu       1
# 22      20030219            call for ethanol blend fuel to go ahead       1
# 23      20030219             carews freak goal leaves roma in ruins       1
# 24      20030219                       cemeteries miss out on funds       1

# %%
#END
